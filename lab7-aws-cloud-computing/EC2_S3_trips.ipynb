# %% [markdown]
# ### Access your data in S3 through EC2
# This notebook will introduce how to access file from S3 and use pandas to analyze the citibike data trips in New York City. You can download the citibik trip data from, https://s3.amazonaws.com/tripdata/index.html

# %%
# !pip install boto3
# !pip install smart_open
# Out:
# Requirement already satisfied: boto3 in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (1.17.27)
# Requirement already satisfied: botocore<1.21.0,>=1.20.27 in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (from boto3) (1.20.27)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (from boto3) (0.3.4)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.27->boto3) (1.26.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.27->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.27->boto3) (1.15.0)
# Requirement already satisfied: smart_open in ./anaconda3/envs/geospatial/lib/python3.8/site-packages (4.2.0)

# %% [markdown]
# #### Check all available buckets in the S3

# %%
import boto3, os


# Configure you AWS credentials, google how to find your access key id and access key
os.environ["AWS_ACCESS_KEY_ID"] = "your_access_key_id"
os.environ["AWS_SECRET_ACCESS_KEY"] = "your_secret_access_key"

# Create S3 resource
s3 = boto3.resource('s3')

s3 = boto3.resource('s3')

for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# aws-logs-339851289029-us-east-1
# bsds-ec
# my-first-emr-cluster
# www.urbanspatial.info

# %% [markdown]
# #### Loop the file list in the cluster, use your own bucket name to replace `my-first-emr-cluster` here.

# %%
# loop all csv file in my S3 buckets
import pandas as pd

for obj in s3.Bucket(name='my-first-emr-cluster').objects.all():
    filename = os.path.join(obj.bucket_name, obj.key)
    
    if obj.key.endswith('.csv'): 
        print(obj.key)
# Out:
# 2013-07 - Citi Bike trip data.csv
# 2013-08 - Citi Bike trip data.csv
# 2013-09 - Citi Bike trip data.csv
# 2013-10 - Citi Bike trip data.csv
# 2013-11 - Citi Bike trip data.csv
# 2013-12 - Citi Bike trip data.csv
# 2014-01 - Citi Bike trip data.csv
# 2014-02 - Citi Bike trip data.csv
# 2014-03 - Citi Bike trip data.csv
# 2014-04 - Citi Bike trip data.csv
# 2014-05 - Citi Bike trip data.csv
# 2014-06 - Citi Bike trip data.csv
# 2014-07 - Citi Bike trip data.csv
# 2014-08 - Citi Bike trip data.csv
# 201409-citibike-tripdata.csv
# patterns-part1.csv
# tutorialEMR/Condom_distribution_sites.csv
# uber-raw-data-apr14.csv
# uber-raw-data-aug14.csv
# uber-raw-data-jul14.csv
# uber-raw-data-jun14.csv
# uber-raw-data-may14.csv
# uber-raw-data-sep14.csv

# %% [markdown]
# #### Open the files in S3 using the EC2
# Go to your S3 and locate your file

# %%
from smart_open import smart_open

path = "s3n://my-first-emr-cluster/2014-03 - Citi Bike trip data.csv"

df = pd.read_csv(smart_open(path))

# %%
df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           949  2014-03-01 00:00:16  2014-03-01 00:16:05               317
# 1           533  2014-03-01 00:00:57  2014-03-01 00:09:50               457
# 2           122  2014-03-01 00:01:06  2014-03-01 00:03:08               146
# 3           134  2014-03-01 00:01:14  2014-03-01 00:03:28               146
# 4           997  2014-03-01 00:01:18  2014-03-01 00:17:55               150
#
#      start station name  start station latitude  start station longitude  \
# 0     E 6 St & Avenue B               40.724537               -73.981854
# 1    Broadway & W 58 St               40.766953               -73.981693
# 2  Hudson St & Reade St               40.716250               -74.009106
# 3  Hudson St & Reade St               40.716250               -74.009106
# 4     E 2 St & Avenue C               40.720874               -73.980858
#
#    end station id         end station name  end station latitude  \
# 0             284    Greenwich Ave & 8 Ave             40.739017
# 1             441          E 52 St & 2 Ave             40.756014
# 2             276  Duane St & Greenwich St             40.717488
# 3             276  Duane St & Greenwich St             40.717488
# 4             461          E 20 St & 2 Ave             40.735877
#
#    end station longitude  bikeid    usertype birth year  gender
# 0             -74.002638   17440  Subscriber       1942       1
# 1             -73.967416   20855  Subscriber       1960       1
# 2             -74.010455   15822  Subscriber       1984       1
# 3             -74.010455   17793  Subscriber       1985       1
# 4             -73.982050   20756  Subscriber       1977       1

# %% [markdown]
# ### Rename the columns of of the dataframe
# Remove the space in names would be easier for the following indexing

# %%
df_bike = df.rename(columns={"start station id": "start_station_id", 
                             "start station name": "start_station_name",
                             "start station latitude": "start_station_lat",
                             "start station longitude": "start_station_lon", 
                             "end station id": "end_station_id", 
                             "end station name": "end_station_name", 
                             "end station latitude": "end_station_lat",
                             "end station longitude": "end_station_lon", 
                             "birth year": "birth_year"})
df_bike.head()
# Out:
#    tripduration            starttime             stoptime  start_station_id  \
# 0           949  2014-03-01 00:00:16  2014-03-01 00:16:05               317
# 1           533  2014-03-01 00:00:57  2014-03-01 00:09:50               457
# 2           122  2014-03-01 00:01:06  2014-03-01 00:03:08               146
# 3           134  2014-03-01 00:01:14  2014-03-01 00:03:28               146
# 4           997  2014-03-01 00:01:18  2014-03-01 00:17:55               150
#
#      start_station_name  start_station_lat  start_station_lon  end_station_id  \
# 0     E 6 St & Avenue B          40.724537         -73.981854             284
# 1    Broadway & W 58 St          40.766953         -73.981693             441
# 2  Hudson St & Reade St          40.716250         -74.009106             276
# 3  Hudson St & Reade St          40.716250         -74.009106             276
# 4     E 2 St & Avenue C          40.720874         -73.980858             461
#
#           end_station_name  end_station_lat  end_station_lon  bikeid  \
# 0    Greenwich Ave & 8 Ave        40.739017       -74.002638   17440
# 1          E 52 St & 2 Ave        40.756014       -73.967416   20855
# 2  Duane St & Greenwich St        40.717488       -74.010455   15822
# 3  Duane St & Greenwich St        40.717488       -74.010455   17793
# 4          E 20 St & 2 Ave        40.735877       -73.982050   20756
#
#      usertype birth_year  gender
# 0  Subscriber       1942       1
# 1  Subscriber       1960       1
# 2  Subscriber       1984       1
# 3  Subscriber       1985       1
# 4  Subscriber       1977       1

# %% [markdown]
# ### Count the number of trajectories from and stop at different stations

# %%
start_station = df_bike.groupby('start_station_id').size().to_frame('size')
start_station
# Out:
#                   size
# start_station_id
# 72                1433
# 79                1012
# 82                 563
# 83                 615
# 116               2628
# ...                ...
# 2017               649
# 2021              1411
# 2022               800
# 2023               682
# 3002              1724
#
# [331 rows x 1 columns]

# %%
end_station = df_bike.groupby('end_station_id').size().to_frame('size')
end_station
# Out:
#                 size
# end_station_id
# 72              1340
# 79              1039
# 82               583
# 83               636
# 116             2655
# ...              ...
# 2017             542
# 2021            1382
# 2022             907
# 2023             683
# 3002            1891
#
# [331 rows x 1 columns]

# %% [markdown]
# #### Rename the axis and prepare for merging
# The start station and the end station are both the station id, we cand change the number both as station id

# %%
s_station = start_station.rename_axis("station_id")
e_station = end_station.rename_axis("station_id")

# %% [markdown]
# #### Merge the start and end station dataframes

# %%
SE_station = s_station.merge(e_station, on='station_id')

# rename the size column as number of trips start and end
SE_station = SE_station.rename(columns={"size_x": 'start', "size_y": "end"})
SE_station.head()
# Out:
#             start   end
# station_id
# 72           1433  1340
# 79           1012  1039
# 82            563   583
# 83            615   636
# 116          2628  2655

# %% [markdown]
# #### Our table has no spatial information, we need join with the original data that has the cooridnate information
# Change the index name back to the start_station_id, we going to use this join with the original table.

# %%
SE_station = SE_station.rename_axis("start_station_id")
SE_station
# Out:
#                   start   end
# start_station_id
# 72                 1433  1340
# 79                 1012  1039
# 82                  563   583
# 83                  615   636
# 116                2628  2655
# ...                 ...   ...
# 2017                649   542
# 2021               1411  1382
# 2022                800   907
# 2023                682   683
# 3002               1724  1891
#
# [330 rows x 2 columns]

# %% [markdown]
# #### Our table has no spatial information, we need join with the original data that has the cooridnate information
# Change the index name back to the start_station_id, we going to use this join with the original table.

# %%
SE_station = SE_station.rename_axis("start_station_id")
SE_station
# Out:
#                   start   end
# start_station_id
# 72                 1433  1340
# 79                 1012  1039
# 82                  563   583
# 83                  615   636
# 116                2628  2655
# ...                 ...   ...
# 2017                649   542
# 2021               1411  1382
# 2022                800   907
# 2023                682   683
# 3002               1724  1891
#
# [330 rows x 2 columns]

# %% [markdown]
# #### Extract the lon, lat of each stations by removing all duplicate stations info, and then merge with the created table

# %%
df_bike_coord = df_bike.drop_duplicates(subset = ["start_station_id"])

df_bike_coord = df_bike_coord.merge(SE_station, on="start_station_id")
df_bike_coord
# Out:
#      tripduration            starttime             stoptime  start_station_id  \
# 0             949  2014-03-01 00:00:16  2014-03-01 00:16:05               317
# 1             533  2014-03-01 00:00:57  2014-03-01 00:09:50               457
# 2             122  2014-03-01 00:01:06  2014-03-01 00:03:08               146
# 3             997  2014-03-01 00:01:18  2014-03-01 00:17:55               150
# 4             720  2014-03-01 00:01:27  2014-03-01 00:13:27               382
# ..            ...                  ...                  ...               ...
# 325           717  2014-03-02 16:04:08  2014-03-02 16:16:05              2005
# 326           879  2014-03-02 19:47:56  2014-03-02 20:02:35               443
# 327           911  2014-03-03 12:26:07  2014-03-03 12:41:18              2001
# 328          1198  2014-03-05 08:28:03  2014-03-05 08:48:01               431
# 329           704  2014-03-21 15:31:18  2014-03-21 15:43:02               253
#
#              start_station_name  start_station_lat  start_station_lon  \
# 0             E 6 St & Avenue B          40.724537         -73.981854
# 1            Broadway & W 58 St          40.766953         -73.981693
# 2          Hudson St & Reade St          40.716250         -74.009106
# 3             E 2 St & Avenue C          40.720874         -73.980858
# 4       University Pl & E 14 St          40.734927         -73.992005
# ..                          ...                ...                ...
# 325      Railroad Ave & Kay Ave          40.705312         -73.971001
# 326      Bedford Ave & S 9th St          40.708531         -73.964090
# 327         7 Ave & Farragut St          40.698921         -73.973330
# 328  Hanover Pl & Livingston St          40.688646         -73.982634
# 329             W 13 St & 5 Ave          40.735439         -73.994539
#
#      end_station_id           end_station_name  end_station_lat  \
# 0               284      Greenwich Ave & 8 Ave        40.739017
# 1               441            E 52 St & 2 Ave        40.756014
# 2               276    Duane St & Greenwich St        40.717488
# 3               461            E 20 St & 2 Ave        40.735877
# 4                79   Franklin St & W Broadway        40.719116
# ..              ...                        ...              ...
# 325             271     Ashland Pl & Hanson Pl        40.685282
# 326             430           York St & Jay St        40.701485
# 327            2005     Railroad Ave & Kay Ave        40.705312
# 328             395  Bond St & Schermerhorn St        40.688070
# 329             151   Cleveland Pl & Spring St        40.721816
#
#      end_station_lon  bikeid    usertype birth_year  gender  start   end
# 0         -74.002638   17440  Subscriber       1942       1    544   744
# 1         -73.967416   20855  Subscriber       1960       1   2182  1898
# 2         -74.010455   15822  Subscriber       1984       1    880   872
# 3         -73.982050   20756  Subscriber       1977       1   1841  1627
# 4         -74.006667   19377  Subscriber       1983       1   2643  2943
# ..               ...     ...         ...        ...     ...    ...   ...
# 325       -73.978058   14850  Subscriber       1984       1     74    83
# 326       -73.986569   15590  Subscriber       1986       1     77    77
# 327       -73.971001   18370  Subscriber       1990       1    118   106
# 328       -73.984106   17784  Subscriber       1970       1     79    83
# 329       -73.997203   18919  Subscriber       1970       2    104    98
#
# [330 rows x 17 columns]

# %% [markdown]
# #### Create a GeoPandas based on the lon, lat info in the dataframe

# %%
# from shapely.geometry import Point
# from geopandas import GeoDataFrame

# geometry = [Point(xy) for xy in zip(df_bike_coord.end_station_lon, df_bike_coord.end_station_lat)]
# gdf = GeoDataFrame(df_bike_coord, crs="EPSG:4326", geometry=geometry)

from geopandas import GeoDataFrame as gdf
import geopandas as gpd
import pandas as pd

crs = {'init': 'epsg:4326'} #http://www.spatialreference.org/ref/epsg/2263/

# create a geo-dataframe
points_gdf= gpd.GeoDataFrame(df_bike_coord, crs=crs, \
                geometry=gpd.points_from_xy(df_bike_coord.end_station_lon, df_bike_coord.end_station_lat))

# save the geo-dataframe as a shapefile
points_gdf.to_file("stations.json")

# %% [markdown]
# ### Copy your file from EC2 to your local computer
# Transfer my notebook from EC2 to my local computer, type the following commands in your terminal,
#
# `scp ubuntu@ec2-54-90-90-167.compute-1.amazonaws.com:/home/ubuntu/EC2_S3_trips.ipynb .`
#
# Transfer the shapefile to local computer,
#
# `scp ubuntu@ec2-54-90-90-167.compute-1.amazonaws.com:/home/ubuntu/stations.* .`

# %% [markdown]
# ### Homework:
# Map the number of female (gender 2) cyclists older than 40 (birth year before 1971) start and end at different stations in Citibike data of August, 2018. Upload the bike data to S3 and do your analysis in your EC2 instance. Submit the map and your notebook to the Canvas. The citibike data can be download here, https://s3.amazonaws.com/tripdata/index.html
