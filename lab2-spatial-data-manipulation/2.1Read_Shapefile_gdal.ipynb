# %% [markdown]
# ## This part is used read the shapefile using gdal
# GDAL is free, light, and open source, and it is available on Linux
# knowing how to use gdal to manipute the spatial data will give you
# a lot of flexibility in spatial analysis

# %%
# This function is used to read the features and attribute of shapefile using gdal

import ogr, osr
import os, os.path

# create shapefile of the generated sample site
coffee_shop = 'sample-data/Cambridge-coffee-shop.shp'

# open shapefile and loop all features
driver = ogr.GetDriverByName("ESRI Shapefile")
datasource = driver.Open(coffee_shop, 0)
layer = datasource.GetLayer()

for feat in layer:
    id = feat.GetField('name')
    print('The panoid is:', id)
# Out:
# ('The panoid is:', '1369 Coffee House')
# ('The panoid is:', '1369 Coffee House')
# ('The panoid is:', 'Aceituna Cafe')
# ('The panoid is:', "Al's Deli Cafe-Cambridge")
# ('The panoid is:', 'Algiers Coffee House')
# ('The panoid is:', 'Area Four')
# ('The panoid is:', 'B & B Snack Bar')
# ('The panoid is:', 'Basha Cafe')
# ('The panoid is:', 'Beantowne Coffee House')
# ('The panoid is:', 'Boston Tea Stop')
# ('The panoid is:', 'Broadway Marketplace LLC')
# ('The panoid is:', 'Cafe Avec')
# ('The panoid is:', 'Cafe Pamplona')
# ('The panoid is:', 'Cafe Zing')
# ('The panoid is:', 'Cambridge Coffee Shop')
# ('The panoid is:', 'Central Brew Cafe & Espresso')
# ('The panoid is:', 'Conroy Commons')
# ('The panoid is:', 'Crema Cafe')
# ('The panoid is:', 'Dado Tea')
# ('The panoid is:', 'Dado Tea 50 Church Street')
# ('The panoid is:', "Darwin's Limited")
# ('The panoid is:', "Darwin's Limited")
# ('The panoid is:', 'Discovery Cafe')
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', "Dunkin' Donuts")
# ('The panoid is:', 'Dwell Time')
# ('The panoid is:', 'Expresso Cafe')
# ('The panoid is:', 'Fort Point Tea Co')
# ('The panoid is:', 'Harvard Dining Svc')
# ('The panoid is:', 'Hub Donuts Inc')
# ('The panoid is:', 'Hub Donuts Inc')
# ('The panoid is:', 'Kendall Kitchen')
# ('The panoid is:', 'LA Luna Caffe')
# ('The panoid is:', 'Mariposa Bakery')
# ('The panoid is:', 'Museum Market')
# ('The panoid is:', 'Sebastians')
# ('The panoid is:', "Darwin's Limited")
# ('The panoid is:', "Peet's Coffee & Tea")
# ('The panoid is:', 'Plaza Catering')
# ('The panoid is:', 'Qafe')
# ('The panoid is:', 'R J Gourmet')
# ('The panoid is:', "Simon's Too")
# ('The panoid is:', 'Singa Bella Cafe')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Sunset Cafe Inc')
# ('The panoid is:', 'Sweet Touch Cafe')
# ('The panoid is:', 'Tasin & Coffee Express')
# ('The panoid is:', 'Tealuxe')
# ('The panoid is:', 'Teavana')
# ('The panoid is:', 'Tisan Coffee Express')
# ('The panoid is:', 'Tisan Coffee Express')
# ('The panoid is:', "Verna's Donut Shop")
# ('The panoid is:', 'Voltage Coffee & Art')
# ('The panoid is:', 'Wu Healing Ctr')
# ('The panoid is:', "Simon's Coffee Shop")
# ('The panoid is:', 'Starbucks')
# ('The panoid is:', 'Bourbon Coffee')
